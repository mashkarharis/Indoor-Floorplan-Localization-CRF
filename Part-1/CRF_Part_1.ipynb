# %% [markdown]
# # Inertial + Floorplan Localization Using CRF

# %% [markdown]
# ## Paper

# %% [markdown]
# This implementation is based on the researches done on the following papers,

# %% [markdown]
# [1]	Z. Xiao, H. Wen, A. Markham, και N. Trigoni, ‘Lightweight map matching for indoor localisation using conditional random fields’, στο IPSN-14 proceedings of the 13th international symposium on information processing in sensor networks, 2014, σσ. 131–142.
#
# [2]	J. Zhang, M. Ren, P. Wang, J. Meng, και Y. Mu, ‘Indoor localization based on VIO system and three-dimensional map matching’, Sensors, τ. 20, τχ. 10, σ. 2790, 2020.

# %% [markdown]
# Note that due to unavailability of exact dataset used for above researchers, I had to use following dataset and convert that accordingly.

# %% [markdown]
# [3] S. Herath, S. Irandoust, B. Chen, Y. Qian, P. Kim, και Y. Furukawa, ‘Fusion-DHL: WiFi, IMU, and Floorplan Fusion for Dense History of Locations in Indoor Environments’, στο 2021 IEEE International Conference on Robotics and Automation (ICRA), 2021, σσ. 5677–5683.

# %% [markdown]
# ## Theory

# %% [markdown]
# In this notebook, I am going to implement indoor localization mechanism using Linear Chain Conditional Random Fields. By using this model we can predict location of a user when starting position, IMU observations (velocity vectors) and floorplan of the building is given.

# %% [markdown]
# Inputs,
#
# * Stating Position - (Meters In X direction(TopLeft|LeftRight), Meters In Y direction(TopLeft|TopBottom))
# * Sequence of Velocity Vectors Captured In Small Time Range (20 seconds) : Velocity_Values(ms-1), Velocity_Angles(radian)
# * Graph of Floorplan

# %% [markdown]
# ### Overall Architecture

# %% [markdown]
# Here is the overall system architecture

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The input is a velocity vector observed using IMU data Z = {Z0,...,ZT }, and the task is to predict a sequence of states S = {S0,...,ST } given input Z.

# %% [markdown]
# ### Viterbi Algorithm

# %% [markdown]
# We use Viterbi algorithm, which can dynamically solve the optimal state points sequence that is most likely to produce the currently given observation value sequence. The solution steps of Viterbi algorithm are as follows:

# %% [markdown]
# (1) Initialization: Compute the non-normalized probability of the first position for all states, where m is the number of states.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (2) Recursion: Iterate through each state from front to back, find the maximum value of the non-normalized probability of each state l = 1, 2, · · · , m at position i = 2, 3, · · · , n, and record the state sequence label Ψi(l) with the highest probability.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (3) When i = n, we obtain the maximum value of the non-normalized probability and the terminal
# of the optimal state points sequence

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (4) Calculate the final state points output sequence

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (5) Finally, the optimal sequence of state points is as follows:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Defined F and W

# %% [markdown]
# We can use w and F(y, x) to represent the weight vector and the global state transfer function vector.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# where I(Yt−1, Yt) is an indicator function equal to 1 when states Yt−1 and Yt are connected and 0 otherwise.

# %% [markdown]
# We use two functions f1 anf f2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# where xdt is the Euclidean distance between two consecutive observations, d(yt−1, yt) is the Euclidean distance between two consecutive state points, and σ2d is the variance of the distance in the observation data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# where xθt is the orientation of two consecutive observations, θ(yt−1, yt) is the orientation between two consecutive state points, and σ2θ is the variance of the orientation in the observation data.

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd 
from matplotlib import image
from matplotlib import pyplot as plt
from math import cos, asin, sqrt, pi, atan2

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Here are units we use,
#
# * location coordinates (x,y) : In pixels
# * angle : radian
# * distance - meter
# * velocity - meter per second

# %% [markdown]
# ### Prepare Floorplan

# %% [markdown]
# For this we use Lougheed Floorplan
#
# 2.5 Pixels = 1 m

# %% [markdown]
# ![lougheed_00.png](attachment:lougheed_00.png)

# %% [markdown]
# Here are the constrains,
#
# Coordinate Center - (TOP LEFT, LR-> X+, TB -> Y+)
#
# * Top Left (TL) - (0,0) in pixels, (49.252463,-122.897553) in Lat,Lon
# * Bottom Left (BL) - (0,776) in pixels, (49.249681,-122.897553) in Lat,Lon
# * Top Right (TR) - (887,0) in pixels, (49.252463,-122.892735) in Lat,Lon
# * Bottom Right (BR) - (887,776) in pixels, (49.249681,-122.892735) in Lat,Lon

# %% [markdown]
# Now Let's load data we have. For this we use Fusion Location Provider's Data. (Which is in file FLP)

# %% [markdown]
# Load Data Set 1

# %%
dataset1 = pd.read_csv("dataset1.csv") 
df1=pd.DataFrame(dataset1)
df1.head()
# Out:
#       Column1    Column2     Column3    Column4    Column5   Column6  \
# 0  422.225000  49.250524 -122.896379  21.393999  35.099998  4.599998
# 1  423.342410  49.250518 -122.896356  20.046000  35.099998  4.599998
# 2  424.343861  49.250517 -122.896350  19.625999  35.099998  4.599998
# 3  425.345205  49.250519 -122.896352  18.134001  35.099998  4.599998
# 4  426.340767  49.250519 -122.896351  17.996000  35.099998  4.599998
#
#       Column7  Column8   Column9  Column10
# 0  150.599854      0.0  0.214251       0.0
# 1  121.818413      0.0  0.621120       0.0
# 2  114.648056      0.0  0.525259       0.0
# 3  105.172920      0.0  0.267578       0.0
# 4  101.856239      0.0  0.194385       0.0

# %% [markdown]
# Load Data Set 2

# %%
dataset2 = pd.read_csv("dataset2.csv") 
df2=pd.DataFrame(dataset2)
df2.head()
# Out:
#        Column1    Column2     Column3  Column4    Column5   Column6  \
# 0  4214.342792  49.251212 -122.896010    8.834  39.699997  4.700001
# 1  4215.344235  49.251207 -122.896008    8.408  39.699997  4.700001
# 2  4216.343776  49.251202 -122.896005    7.797  39.699997  4.700001
# 3  4216.973000  49.251198 -122.896002    7.536  35.099998  4.700001
# 4  4218.344638  49.251190 -122.896000    7.042  35.099998  4.700001
#
#       Column7  Column8   Column9  Column10
# 0   97.656136        0  0.000982       0.0
# 1   95.627380        0  0.001220       0.0
# 2   96.607895        0  0.001325       0.0
# 3   95.984741        0  0.002083       0.0
# 4  130.190704        0  0.000306       0.0

# %% [markdown]
# Concat Two Datasets

# %%
df_merged=pd.concat([df1,df2])
df_merged.reset_index(inplace=True, drop=True)
df_merged.head()
# Out:
#       Column1    Column2     Column3    Column4    Column5   Column6  \
# 0  422.225000  49.250524 -122.896379  21.393999  35.099998  4.599998
# 1  423.342410  49.250518 -122.896356  20.046000  35.099998  4.599998
# 2  424.343861  49.250517 -122.896350  19.625999  35.099998  4.599998
# 3  425.345205  49.250519 -122.896352  18.134001  35.099998  4.599998
# 4  426.340767  49.250519 -122.896351  17.996000  35.099998  4.599998
#
#       Column7  Column8   Column9  Column10
# 0  150.599854      0.0  0.214251       0.0
# 1  121.818413      0.0  0.621120       0.0
# 2  114.648056      0.0  0.525259       0.0
# 3  105.172920      0.0  0.267578       0.0
# 4  101.856239      0.0  0.194385       0.0

# %% [markdown]
# Get Dataframe Informations

# %%
print(df1.shape[0])
print(df2.shape[0])
print(df_merged.shape[0])
# Out:
# 986
# 747
# 1733

# %% [markdown]
# Select Only required data

# %%
sub_df=df_merged[['Column1','Column2','Column3']]
sub_df = sub_df.rename(columns={'Column1': 'TimeStamp', 'Column2': 'Latitude','Column3':'Longitude'})
print(sub_df.shape[0])
sub_df.head()
# Out:
# 1733
#     TimeStamp   Latitude   Longitude
# 0  422.225000  49.250524 -122.896379
# 1  423.342410  49.250518 -122.896356
# 2  424.343861  49.250517 -122.896350
# 3  425.345205  49.250519 -122.896352
# 4  426.340767  49.250519 -122.896351

# %% [markdown]
# However we can't deal with Latitude and Longitude, We have to convert it to pixels or meters.

# %%
# Calculate X direction,
# X direction -- Longitude
# X's Plus direction = Longitude's Plus Direction

# Calculate Y direction,
# Y direction -- Latitude
# Y's Plus direction = Latitude's Negative Direction

X_0_in_longitude=-122.897553
Y_0_in_latitude=49.252463
pixelspermeter=2.5
number_of_node_in_graph=30

# Distance between Two Lat,Lon


def distanceLatLonInMeters(lat1, lon1, lat2, lon2):
    p = pi/180
    a = 0.5 - cos((lat2-lat1)*p)/2 + cos(lat1*p) * cos(lat2*p) * (1-cos((lon2-lon1)*p))/2
    return 12742000 * asin(sqrt(a))

x_dir_pixels=[]
y_dir_pixels=[]
x_dir_meters=[]
y_dir_meters=[]

for tuple in sub_df.itertuples():
    meters_in_x_direction=abs(distanceLatLonInMeters(Y_0_in_latitude,X_0_in_longitude,Y_0_in_latitude,tuple[3]))
    meters_in_y_direction=abs(distanceLatLonInMeters(Y_0_in_latitude,X_0_in_longitude,tuple[2],X_0_in_longitude))
    
    pixels_in_x_direction=round(meters_in_x_direction*2.5)
    pixels_in_y_direction=round(meters_in_y_direction*2.5)
    
    x_dir_pixels.append(pixels_in_x_direction)
    y_dir_pixels.append(pixels_in_y_direction)
    
    x_dir_meters.append(meters_in_x_direction)
    y_dir_meters.append(meters_in_y_direction)
    
    ##print(pixels_in_x_direction,pixels_in_y_direction,meters_in_x_direction,meters_in_y_direction)
    
updated_df=sub_df.copy()
updated_df["Pixels In X Direction"] = x_dir_pixels
updated_df["Pixels In Y Direction"] = y_dir_pixels
updated_df["Meters In X Direction"] = x_dir_meters
updated_df["Meters In Y Direction"] = y_dir_meters

# %% [markdown]
# Let's see updated dataframe

# %%
updated_df.head()
# Out:
#     TimeStamp   Latitude   Longitude  Pixels In X Direction  \
# 0  422.225000  49.250524 -122.896379                    213
# 1  423.342410  49.250518 -122.896356                    217
# 2  424.343861  49.250517 -122.896350                    218
# 3  425.345205  49.250519 -122.896352                    218
# 4  426.340767  49.250519 -122.896351                    218
#
#    Pixels In Y Direction  Meters In X Direction  Meters In Y Direction
# 0                    539              85.208858             215.606966
# 1                    541              86.878209             216.274132
# 2                    541              87.313688             216.385327
# 3                    540              87.168528             216.162941
# 4                    540              87.241094             216.162941

# %% [markdown]
# Load Image and Mark Visited Areas

# %%
floorplan0 = image.imread('lougheed_00 - Copy.png')
plt.imshow(floorplan0)
for row in updated_df.itertuples():
    plt.plot(row[4],row[5] , marker=',', color="red")
plt.savefig('visited_areas.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Now We can see that the area where measurements are taken

# %% [markdown]
# Now let's select random points to create graphs. In here we should **create several connected graph and give them unique graph ids**. However, the map we selected contains only one connected graph.

# %% [markdown]
# After drawing several map graphs found that random state 31 gives best graph, but need some adjustments.

# %%
graph=[] # contains list of dictionaries which has fields namely -> "nodeid","x_dir_pixels","y_dir_pixels","connected_graph_id"
randomly_selected_subset=updated_df.sample(n = number_of_node_in_graph, random_state = 31)
i=0
for row in randomly_selected_subset.itertuples():
    graph.append({"nodeid":i,"x_dir_pixels":row[4],"y_dir_pixels":row[5],"connected_graph_id":"G1"})
    i+=1

# %% [markdown]
# Let's draw graph,

# %%
floorplan1 = image.imread('lougheed_00 - Copy.png')
plt.figure(figsize = (10,10))
plt.imshow(floorplan1)
for row in graph:
    plt.plot(row["x_dir_pixels"],row["y_dir_pixels"] , marker='*', color="blue")
plt.show()

# %% [markdown]
# Doing Adjustments

# %%
graphtable=pd.DataFrame(graph)
graphtable
# Out:
#     nodeid  x_dir_pixels  y_dir_pixels connected_graph_id
# 0        0           392           285                 G1
# 1        1           283           353                 G1
# 2        2           445           357                 G1
# 3        3           447           442                 G1
# 4        4           325           333                 G1
# 5        5           308           228                 G1
# 6        6           283           415                 G1
# 7        7           237           500                 G1
# 8        8           265           493                 G1
# 9        9           269           436                 G1
# 10      10           261           513                 G1
# 11      11           258           470                 G1
# 12      12           390           498                 G1
# 13      13           341           483                 G1
# 14      14           263           449                 G1
# 15      15           266           366                 G1
# 16      16           275           319                 G1
# 17      17           282           463                 G1
# 18      18           282           306                 G1
# 19      19           384           494                 G1
# 20      20           286           331                 G1
# 21      21           283           332                 G1
# 22      22           285           369                 G1
# 23      23           218           540                 G1
# 24      24           438           323                 G1
# 25      25           289           390                 G1
# 26      26           329           259                 G1
# 27      27           232           534                 G1
# 28      28           371           283                 G1
# 29      29           282           242                 G1

# %%
graph=[{'nodeid': 0, 'x_dir_pixels': 392, 'y_dir_pixels': 285, 'connected_graph_id': 'G1'}, {'nodeid': 1, 'x_dir_pixels': 283, 'y_dir_pixels': 353, 'connected_graph_id': 'G1'}, {'nodeid': 2, 'x_dir_pixels': 445, 'y_dir_pixels': 357, 'connected_graph_id': 'G1'}, {'nodeid': 3, 'x_dir_pixels': 447, 'y_dir_pixels': 442, 'connected_graph_id': 'G1'}, {'nodeid': 4, 'x_dir_pixels': 280, 'y_dir_pixels': 270, 'connected_graph_id': 'G1'}, {'nodeid': 5, 'x_dir_pixels': 308, 'y_dir_pixels': 228, 'connected_graph_id': 'G1'}, {'nodeid': 6, 'x_dir_pixels': 283, 'y_dir_pixels': 415, 'connected_graph_id': 'G1'}, {'nodeid': 7, 'x_dir_pixels': 260, 'y_dir_pixels': 550, 'connected_graph_id': 'G1'}, {'nodeid': 8, 'x_dir_pixels': 265, 'y_dir_pixels': 493, 'connected_graph_id': 'G1'}, {'nodeid': 9, 'x_dir_pixels': 269, 'y_dir_pixels': 436, 'connected_graph_id': 'G1'}, {'nodeid': 10, 'x_dir_pixels': 261, 'y_dir_pixels': 513, 'connected_graph_id': 'G1'}, {'nodeid': 11, 'x_dir_pixels': 258, 'y_dir_pixels': 470, 'connected_graph_id': 'G1'}, {'nodeid': 12, 'x_dir_pixels': 390, 'y_dir_pixels': 500, 'connected_graph_id': 'G1'}, {'nodeid': 13, 'x_dir_pixels': 341, 'y_dir_pixels': 500, 'connected_graph_id': 'G1'}, {'nodeid': 14, 'x_dir_pixels': 263, 'y_dir_pixels': 449, 'connected_graph_id': 'G1'}, {'nodeid': 15, 'x_dir_pixels': 266, 'y_dir_pixels': 366, 'connected_graph_id': 'G1'}, {'nodeid': 16, 'x_dir_pixels': 275, 'y_dir_pixels': 319, 'connected_graph_id': 'G1'}, {'nodeid': 17, 'x_dir_pixels': 282, 'y_dir_pixels': 463, 'connected_graph_id': 'G1'}, {'nodeid': 18, 'x_dir_pixels': 282, 'y_dir_pixels': 306, 'connected_graph_id': 'G1'}, {'nodeid': 19, 'x_dir_pixels': 440, 'y_dir_pixels': 500, 'connected_graph_id': 'G1'}, {'nodeid': 20, 'x_dir_pixels': 286, 'y_dir_pixels': 331, 'connected_graph_id': 'G1'}, {'nodeid': 21, 'x_dir_pixels': 283, 'y_dir_pixels': 332, 'connected_graph_id': 'G1'}, {'nodeid': 22, 'x_dir_pixels': 285, 'y_dir_pixels': 369, 'connected_graph_id': 'G1'}, {'nodeid': 23, 'x_dir_pixels': 230, 'y_dir_pixels': 540, 'connected_graph_id': 'G1'}, {'nodeid': 24, 'x_dir_pixels': 438, 'y_dir_pixels': 323, 'connected_graph_id': 'G1'}, {'nodeid': 25, 'x_dir_pixels': 289, 'y_dir_pixels': 390, 'connected_graph_id': 'G1'}, {'nodeid': 26, 'x_dir_pixels': 329, 'y_dir_pixels': 240, 'connected_graph_id': 'G1'}, {'nodeid': 27, 'x_dir_pixels': 200, 'y_dir_pixels': 550, 'connected_graph_id': 'G1'}, {'nodeid': 28, 'x_dir_pixels': 371, 'y_dir_pixels': 265, 'connected_graph_id': 'G1'}, {'nodeid': 29, 'x_dir_pixels': 282, 'y_dir_pixels': 242, 'connected_graph_id': 'G1'}]
graphtable=pd.DataFrame(graph)
graphtable
# Out:
#     nodeid  x_dir_pixels  y_dir_pixels connected_graph_id
# 0        0           392           285                 G1
# 1        1           283           353                 G1
# 2        2           445           357                 G1
# 3        3           447           442                 G1
# 4        4           280           270                 G1
# 5        5           308           228                 G1
# 6        6           283           415                 G1
# 7        7           260           550                 G1
# 8        8           265           493                 G1
# 9        9           269           436                 G1
# 10      10           261           513                 G1
# 11      11           258           470                 G1
# 12      12           390           500                 G1
# 13      13           341           500                 G1
# 14      14           263           449                 G1
# 15      15           266           366                 G1
# 16      16           275           319                 G1
# 17      17           282           463                 G1
# 18      18           282           306                 G1
# 19      19           440           500                 G1
# 20      20           286           331                 G1
# 21      21           283           332                 G1
# 22      22           285           369                 G1
# 23      23           230           540                 G1
# 24      24           438           323                 G1
# 25      25           289           390                 G1
# 26      26           329           240                 G1
# 27      27           200           550                 G1
# 28      28           371           265                 G1
# 29      29           282           242                 G1

# %% [markdown]
# Draw Updated Graph

# %%
floorplan1 = image.imread('lougheed_00 - Copy.png')
plt.figure(figsize = (10,10))
plt.imshow(floorplan1)
for row in graph:
    plt.plot(row["x_dir_pixels"],row["y_dir_pixels"] , marker='.', color="red")
plt.savefig('floor_plan_graph.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Now we have successfully created a graph for the floor plan

# %% [markdown]
# ### Prepare DataSet

# %% [markdown]
# Let's revisit updated_df

# %%
updated_df
# Out:
#         TimeStamp   Latitude   Longitude  Pixels In X Direction  \
# 0      422.225000  49.250524 -122.896379                    213
# 1      423.342410  49.250518 -122.896356                    217
# 2      424.343861  49.250517 -122.896350                    218
# 3      425.345205  49.250519 -122.896352                    218
# 4      426.340767  49.250519 -122.896351                    218
# ...           ...        ...         ...                    ...
# 1728  5139.091000  49.250493 -122.896482                    194
# 1729  5139.592000  49.250492 -122.896509                    189
# 1730  5140.198000  49.250492 -122.896525                    187
# 1731  5140.773000  49.250491 -122.896546                    183
# 1732  5141.852000  49.250491 -122.896573                    178
#
#       Pixels In Y Direction  Meters In X Direction  Meters In Y Direction
# 0                       539              85.208858             215.606966
# 1                       541              86.878209             216.274132
# 2                       541              87.313688             216.385327
# 3                       540              87.168528             216.162941
# 4                       540              87.241094             216.162941
# ...                     ...                    ...                    ...
# 1728                    548              77.733134             219.053999
# 1729                    548              75.773474             219.165203
# 1730                    548              74.612179             219.165203
# 1731                    548              73.088002             219.276392
# 1732                    548              71.128362             219.276392
#
# [1733 rows x 7 columns]

# %% [markdown]
# Denfine Helper Functions

# %%
def calcVelocityVal(prev_row,row):
    distance=sqrt((row[6]-prev_row[6])**2+(row[7]-prev_row[7])**2)
    timediff=row[1]-prev_row[1]
    return distance/timediff

def calcVelocityAngle(prev_row,row):
    return atan2(row[7]-prev_row[7], row[6]-prev_row[6])

def calcNearestState(row):
    
    currentNearestStateID=None
    minDistance=float('inf')
    
    for points in graph:
        
        stateid=points["nodeid"]
        distanceToState=sqrt((points['y_dir_pixels']-row[5])**2+(points['x_dir_pixels']-row[4])**2)
        
        if distanceToState<=minDistance:
            minDistance=distanceToState
            currentNearestStateID=stateid
    return currentNearestStateID

# %% [markdown]
# Now let's calculate velocities and nearest states

# %%
velocity_value=["N/A"]
velocity_angle=["N/A"]
nearest_state=["N/A"]
isValid=[]
prev_row=None

for row in updated_df.itertuples():
   
    # Process First Value
    if row[0]==0:
        prev_row=row
        isValid.append(0)
        continue
        
    timediff=row[1]-prev_row[1]
    if timediff>=2:
        isValid.append(0)
    else:
        isValid.append(1)
    
        
    velocity_value.append(calcVelocityVal(prev_row,row))
    velocity_angle.append(calcVelocityAngle(prev_row,row))
    nearest_state.append(calcNearestState(row))
    prev_row=row
    
updated_df["Velocity_Value"]=velocity_value
updated_df["Velocity_Angle"]=velocity_angle
updated_df["Nearest_State"]=nearest_state
updated_df["isValid"]=isValid

# %% [markdown]
# Let's check new dataframe

# %%
updated_df
# Out:
#         TimeStamp   Latitude   Longitude  Pixels In X Direction  \
# 0      422.225000  49.250524 -122.896379                    213
# 1      423.342410  49.250518 -122.896356                    217
# 2      424.343861  49.250517 -122.896350                    218
# 3      425.345205  49.250519 -122.896352                    218
# 4      426.340767  49.250519 -122.896351                    218
# ...           ...        ...         ...                    ...
# 1728  5139.091000  49.250493 -122.896482                    194
# 1729  5139.592000  49.250492 -122.896509                    189
# 1730  5140.198000  49.250492 -122.896525                    187
# 1731  5140.773000  49.250491 -122.896546                    183
# 1732  5141.852000  49.250491 -122.896573                    178
#
#       Pixels In Y Direction  Meters In X Direction  Meters In Y Direction  \
# 0                       539              85.208858             215.606966
# 1                       541              86.878209             216.274132
# 2                       541              87.313688             216.385327
# 3                       540              87.168528             216.162941
# 4                       540              87.241094             216.162941
# ...                     ...                    ...                    ...
# 1728                    548              77.733134             219.053999
# 1729                    548              75.773474             219.165203
# 1730                    548              74.612179             219.165203
# 1731                    548              73.088002             219.276392
# 1732                    548              71.128362             219.276392
#
#      Velocity_Value Velocity_Angle Nearest_State  isValid
# 0               N/A            N/A           N/A        0
# 1          1.608839        0.38021            23        1
# 2          0.448801       0.249999            23        1
# 3          0.265213      -2.149096            23        1
# 4           0.07289            0.0            23        1
# ...             ...            ...           ...      ...
# 1728       1.150133      -3.056677            27        1
# 1729       3.917791       3.084907            27        1
# 1730       1.916328       3.141593            27        1
# 1731       2.657787       3.068772            27        1
# 1732       1.816163       3.141593            27        1
#
# [1733 rows x 11 columns]

# %% [markdown]
# Now lets created filtered dataframe which only contains, required columns and valid values

# %%
filtered_df=updated_df.copy()
filtered_df=filtered_df[filtered_df['isValid'] == 1]
filtered_df=filtered_df[["TimeStamp","Meters In X Direction","Meters In Y Direction","Velocity_Value","Velocity_Angle","Nearest_State"]]
filtered_df.reset_index(inplace=True, drop=True)
filtered_df.head()
# Out:
#     TimeStamp  Meters In X Direction  Meters In Y Direction Velocity_Value  \
# 0  423.342410              86.878209             216.274132       1.608839
# 1  424.343861              87.313688             216.385327       0.448801
# 2  425.345205              87.168528             216.162941       0.265213
# 3  426.340767              87.241094             216.162941        0.07289
# 4  427.343544              87.241094             216.162941            0.0
#
#   Velocity_Angle Nearest_State
# 0        0.38021            23
# 1       0.249999            23
# 2      -2.149096            23
# 3            0.0            23
# 4            0.0            23

# %% [markdown]
# Let's check first index of second data set

# %%
print(filtered_df.loc[873:877])
# Out:
#        TimeStamp  Meters In X Direction  Meters In Y Direction Velocity_Value  \
# 873  1724.342825             104.732868             145.887755       0.494914
# 874  1725.344916             105.531256             146.888500       1.277529
# 875  4215.344235             112.136031             139.660827       0.573771
# 876  4216.343776             112.353760             140.216800       0.597361
# 877  4216.973000             112.571511             140.661598       0.787062
#
#     Velocity_Angle Nearest_State
# 873       0.743327            15
# 874       0.897402            15
# 875       1.315392             1
# 876       1.197537             1
# 877       1.115543             1

# %%
first_index_of_second_set=875

# %% [markdown]
# Now Let's create a dataset

# %%
data=[]
for row in filtered_df.loc[19:first_index_of_second_set-1].itertuples():
    datadict={}
    start_x = filtered_df.loc[row[0]-19][1]
    start_y = filtered_df.loc[row[0]-19][2]
    state = row[6]
    datadict["startX"]=start_x
    datadict["startY"]=start_y
    i=0
    for subrow in filtered_df.loc[row[0]-19:row[0]].itertuples():
        datadict["velocity_value_"+str(i+1)]=subrow[4]
        i+=1
    j=0
    for subrow in filtered_df.loc[row[0]-19:row[0]].itertuples():
        datadict["velocity_angle_"+str(j+1)]=subrow[5]
        j+=1
        
    datadict["currentState"]=state
    data.append(datadict)

prepared_dataset1=pd.DataFrame(data)
prepared_dataset1
# Out:
#          startX      startY  velocity_value_1  velocity_value_2  \
# 0     86.878209  216.274132          1.608839          0.448801
# 1     87.313688  216.385327          0.448801          0.265213
# 2     87.168528  216.162941          0.265213          0.072890
# 3     87.241094  216.162941          0.072890          0.000000
# 4     87.241094  216.162941          0.000000          0.072421
# ..          ...         ...               ...               ...
# 851  108.869936  146.999699          0.716452          1.070863
# 852  108.507033  146.443721          1.070863          0.316556
# 853  108.361861  146.221317          0.316556          0.332816
# 854  107.998976  146.221317          0.332816          0.379091
# 855  107.636062  146.110143          0.379091          0.717360
#
#      velocity_value_3  velocity_value_4  velocity_value_5  velocity_value_6  \
# 0            0.265213          0.072890          0.000000          0.072421
# 1            0.072890          0.000000          0.072421          2.113376
# 2            0.000000          0.072421          2.113376          0.826399
# 3            0.072421          2.113376          0.826399          0.069784
# 4            2.113376          0.826399          0.069784          0.102970
# ..                ...               ...               ...               ...
# 851          0.316556          0.332816          0.379091          0.717360
# 852          0.332816          0.379091          0.717360          0.866805
# 853          0.379091          0.717360          0.866805          0.687368
# 854          0.717360          0.866805          0.687368          0.868035
# 855          0.866805          0.687368          0.868035          1.374921
#
#      velocity_value_7  velocity_value_8  ...  velocity_angle_12  \
# 0            2.113376          0.826399  ...          -0.992564
# 1            0.826399          0.069784  ...           0.000000
# 2            0.069784          0.102970  ...           0.297340
# 3            0.102970          0.000000  ...           0.000000
# 4            0.000000          0.108577  ...           0.000000
# ..                ...               ...  ...                ...
# 851          0.866805          0.687368  ...          -1.785032
# 852          0.687368          0.868035  ...          -2.149089
# 853          0.868035          1.374921  ...           3.141593
# 854          1.374921          1.548056  ...           3.141593
# 855          1.548056          1.219290  ...           2.591802
#
#      velocity_angle_13  velocity_angle_14  velocity_angle_15  \
# 0             0.000000           0.297340           0.000000
# 1             0.297340           0.000000           0.000000
# 2             0.000000           0.000000           0.365807
# 3             0.000000           0.365807           0.000000
# 4             0.365807           0.000000           0.000000
# ..                 ...                ...                ...
# 851          -2.149089           3.141593           3.141593
# 852           3.141593           3.141593           2.591802
# 853           3.141593           2.591802           3.141593
# 854           2.591802           3.141593           0.000000
# 855           3.141593           0.000000           1.570796
#
#      velocity_angle_16  velocity_angle_17  velocity_angle_18  \
# 0             0.000000           0.365807           0.000000
# 1             0.365807           0.000000           0.000000
# 2             0.000000           0.000000           0.000000
# 3             0.000000           0.000000           0.000000
# 4             0.000000           0.000000           0.000000
# ..                 ...                ...                ...
# 851           2.591802           3.141593           0.000000
# 852           3.141593           0.000000           1.570796
# 853           0.000000           1.570796           1.570796
# 854           1.570796           1.570796           1.197500
# 855           1.570796           1.197500           1.255366
#
#      velocity_angle_19  velocity_angle_20  currentState
# 0             0.000000           0.000000            23
# 1             0.000000           0.000000            23
# 2             0.000000           0.000000            23
# 3             0.000000           0.000000            23
# 4             0.000000          -0.992525            23
# ..                 ...                ...           ...
# 851           1.570796           1.570796            15
# 852           1.570796           1.197500            15
# 853           1.197500           1.255366            15
# 854           1.255366           0.743327            15
# 855           0.743327           0.897402            15
#
# [856 rows x 43 columns]

# %%
data=[]
for row in filtered_df.loc[first_index_of_second_set:].itertuples():
    datadict={}
    start_x = filtered_df.loc[row[0]-19][1]
    start_y = filtered_df.loc[row[0]-19][2]
    state = row[6]
    datadict["startX"]=start_x
    datadict["startY"]=start_y
    i=0
    for subrow in filtered_df.loc[row[0]-19:row[0]].itertuples():
        datadict["velocity_value_"+str(i+1)]=subrow[4]
        i+=1
    j=0
    for subrow in filtered_df.loc[row[0]-19:row[0]].itertuples():
        datadict["velocity_angle_"+str(j+1)]=subrow[5]
        j+=1
        
    datadict["currentState"]=state
    data.append(datadict)

prepared_dataset2=pd.DataFrame(data)
prepared_dataset2
# Out:
#          startX      startY  velocity_value_1  velocity_value_2  \
# 0    107.055423  146.110143          0.717360          0.866805
# 1    106.547363  146.554919          0.866805          0.687368
# 2    106.039313  147.222090          0.687368          0.868035
# 3    105.894149  146.777309          0.868035          1.374921
# 4    106.039313  145.887755          1.374921          1.548056
# ..          ...         ...               ...               ...
# 673   82.450823  214.050235          0.263278          0.427974
# 674   82.305671  214.272627          0.427974          0.170369
# 675   82.233092  214.495019          0.170369          0.143115
# 676   82.160495  214.606212          0.143115          0.106922
# 677   82.160495  214.717411          0.106922          0.286135
#
#      velocity_value_3  velocity_value_4  velocity_value_5  velocity_value_6  \
# 0            0.687368          0.868035          1.374921          1.548056
# 1            0.868035          1.374921          1.548056          1.219290
# 2            1.374921          1.548056          1.219290          0.698860
# 3            1.548056          1.219290          0.698860          0.453633
# 4            1.219290          0.698860          0.453633          0.648189
# ..                ...               ...               ...               ...
# 673          0.170369          0.143115          0.106922          0.286135
# 674          0.143115          0.106922          0.286135          0.841608
# 675          0.106922          0.286135          0.841608          0.420555
# 676          0.286135          0.841608          0.420555          0.410061
# 677          0.841608          0.420555          0.410061          0.334680
#
#      velocity_value_7  velocity_value_8  ...  velocity_angle_12  \
# 0            1.219290          0.698860  ...           3.141593
# 1            0.698860          0.453633  ...           0.000000
# 2            0.453633          0.648189  ...           1.570796
# 3            0.648189          0.566566  ...           1.570796
# 4            0.566566          0.362281  ...           1.197500
# ..                ...               ...  ...                ...
# 673          0.841608          0.420555  ...           2.775803
# 674          0.420555          0.410061  ...           0.919978
# 675          0.410061          0.334680  ...           1.981209
# 676          0.334680          0.441781  ...           2.487898
# 677          0.441781          0.324184  ...           2.926166
#
#      velocity_angle_13  velocity_angle_14  velocity_angle_15  \
# 0             0.000000           1.570796           1.570796
# 1             1.570796           1.570796           1.197500
# 2             1.570796           1.197500           1.255366
# 3             1.197500           1.255366           0.743327
# 4             1.255366           0.743327           0.897402
# ..                 ...                ...                ...
# 673           0.919978           1.981209           2.487898
# 674           1.981209           2.487898           2.926166
# 675           2.487898           2.926166           2.869924
# 676           2.926166           2.869924           2.844262
# 677           2.869924           2.844262           3.003199
#
#      velocity_angle_16  velocity_angle_17  velocity_angle_18  \
# 0             1.197500           1.255366           0.743327
# 1             1.255366           0.743327           0.897402
# 2             0.743327           0.897402           1.315392
# 3             0.897402           1.315392           1.197537
# 4             1.315392           1.197537           1.115543
# ..                 ...                ...                ...
# 673           2.926166           2.869924           2.844262
# 674           2.869924           2.844262           3.003199
# 675           2.844262           3.003199          -3.056677
# 676           3.003199          -3.056677           3.084907
# 677          -3.056677           3.084907           3.141593
#
#      velocity_angle_19  velocity_angle_20  currentState
# 0             0.897402           1.315392             1
# 1             1.315392           1.197537             1
# 2             1.197537           1.115543             1
# 3             1.115543           1.409048             1
# 4             1.409048           1.570796             1
# ..                 ...                ...           ...
# 673           3.003199          -3.056677            27
# 674          -3.056677           3.084907            27
# 675           3.084907           3.141593            27
# 676           3.141593           3.068772            27
# 677           3.068772           3.141593            27
#
# [678 rows x 43 columns]

# %%
final_prepared_dataset=pd.concat([prepared_dataset1,prepared_dataset2])
final_prepared_dataset.reset_index(inplace=True, drop=True)
final_prepared_dataset
# Out:
#          startX      startY  velocity_value_1  velocity_value_2  \
# 0     86.878209  216.274132          1.608839          0.448801
# 1     87.313688  216.385327          0.448801          0.265213
# 2     87.168528  216.162941          0.265213          0.072890
# 3     87.241094  216.162941          0.072890          0.000000
# 4     87.241094  216.162941          0.000000          0.072421
# ...         ...         ...               ...               ...
# 1529  82.450823  214.050235          0.263278          0.427974
# 1530  82.305671  214.272627          0.427974          0.170369
# 1531  82.233092  214.495019          0.170369          0.143115
# 1532  82.160495  214.606212          0.143115          0.106922
# 1533  82.160495  214.717411          0.106922          0.286135
#
#       velocity_value_3  velocity_value_4  velocity_value_5  velocity_value_6  \
# 0             0.265213          0.072890          0.000000          0.072421
# 1             0.072890          0.000000          0.072421          2.113376
# 2             0.000000          0.072421          2.113376          0.826399
# 3             0.072421          2.113376          0.826399          0.069784
# 4             2.113376          0.826399          0.069784          0.102970
# ...                ...               ...               ...               ...
# 1529          0.170369          0.143115          0.106922          0.286135
# 1530          0.143115          0.106922          0.286135          0.841608
# 1531          0.106922          0.286135          0.841608          0.420555
# 1532          0.286135          0.841608          0.420555          0.410061
# 1533          0.841608          0.420555          0.410061          0.334680
#
#       velocity_value_7  velocity_value_8  ...  velocity_angle_12  \
# 0             2.113376          0.826399  ...          -0.992564
# 1             0.826399          0.069784  ...           0.000000
# 2             0.069784          0.102970  ...           0.297340
# 3             0.102970          0.000000  ...           0.000000
# 4             0.000000          0.108577  ...           0.000000
# ...                ...               ...  ...                ...
# 1529          0.841608          0.420555  ...           2.775803
# 1530          0.420555          0.410061  ...           0.919978
# 1531          0.410061          0.334680  ...           1.981209
# 1532          0.334680          0.441781  ...           2.487898
# 1533          0.441781          0.324184  ...           2.926166
#
#       velocity_angle_13  velocity_angle_14  velocity_angle_15  \
# 0              0.000000           0.297340           0.000000
# 1              0.297340           0.000000           0.000000
# 2              0.000000           0.000000           0.365807
# 3              0.000000           0.365807           0.000000
# 4              0.365807           0.000000           0.000000
# ...                 ...                ...                ...
# 1529           0.919978           1.981209           2.487898
# 1530           1.981209           2.487898           2.926166
# 1531           2.487898           2.926166           2.869924
# 1532           2.926166           2.869924           2.844262
# 1533           2.869924           2.844262           3.003199
#
#       velocity_angle_16  velocity_angle_17  velocity_angle_18  \
# 0              0.000000           0.365807           0.000000
# 1              0.365807           0.000000           0.000000
# 2              0.000000           0.000000           0.000000
# 3              0.000000           0.000000           0.000000
# 4              0.000000           0.000000           0.000000
# ...                 ...                ...                ...
# 1529           2.926166           2.869924           2.844262
# 1530           2.869924           2.844262           3.003199
# 1531           2.844262           3.003199          -3.056677
# 1532           3.003199          -3.056677           3.084907
# 1533          -3.056677           3.084907           3.141593
#
#       velocity_angle_19  velocity_angle_20  currentState
# 0              0.000000           0.000000            23
# 1              0.000000           0.000000            23
# 2              0.000000           0.000000            23
# 3              0.000000           0.000000            23
# 4              0.000000          -0.992525            23
# ...                 ...                ...           ...
# 1529           3.003199          -3.056677            27
# 1530          -3.056677           3.084907            27
# 1531           3.084907           3.141593            27
# 1532           3.141593           3.068772            27
# 1533           3.068772           3.141593            27
#
# [1534 rows x 43 columns]

# %% [markdown]
# ### Save Outcomes

# %% [markdown]
# Now let's save out results

# %%
graphtable.to_csv("floor_plan_graph.csv", encoding='utf-8', index=False)
final_prepared_dataset.to_csv("final_prepared_dataset.csv", encoding='utf-8', index=False)
